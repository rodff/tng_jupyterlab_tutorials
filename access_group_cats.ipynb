# %% [markdown]
# ## How to access group catalog data in JupyterLab

# %% [markdown]
# First, it is necessary to load the ```illustris_python``` module.

# %%
import illustris_python as il

# %% [markdown]
# Then, we define the path to files of the simulation of interest, and the snapshot we want to analyse:

# %%
basePath = '../sims.TNG/TNG100-1/output'  # Change this file according to your directory structure
snapshot = 99

# %% [markdown]
# Finally, to access the group catalogs, we methods from the ```illustris_python``` module:

# %%
# Specify just some columns of interest
fields = ['SubhaloMass','SubhaloSFRinRad']   

# Load the sliced group catalog of subhalos
subhalos = il.groupcat.loadSubhalos(basePath, snapshot, fields=fields)

# %% [markdown]
# The subhalo catalog is loaded in the form of a dictionary:

# %%
subhalos
# Out:
# {'count': 4371211,
#  'SubhaloMass': array([2.74779355e+04, 3.66662280e+03, 7.73455505e+02, ...,
#         1.51672289e-02, 1.46616548e-02, 1.41560799e-02]),
#  'SubhaloSFRinRad': array([0.19582452, 0.08808479, 5.29421473, ..., 0.        , 0.        ,
#         0.        ])}

# %% [markdown]
# Each columns is represent by a string in the dictionary, and the data is stored as an numpy.array.
#
# ***
#
# You can also load the full catalog by not specifying the ```fields``` argument:

# %%
# Load the whole group catalog of subhalos
subhalos = il.groupcat.loadSubhalos(basePath, snapshot)

# %%
subhalos
# Out:
# {'count': 4371211,
#  'SubhaloBHMass': array([0.70094055, 0.12551759, 0.17748705, ..., 0.        , 0.        ,
#         0.        ]),
#  'SubhaloBHMdot': array([0.00039801, 0.00023013, 0.00105399, ..., 0.        , 0.        ,
#         0.        ]),
#  'SubhaloBfldDisk': array([1.55439973, 0.90148443, 2.24357772, ...,        nan,        nan,
#                nan]),
#  'SubhaloBfldHalo': array([0.20546156, 0.15268138, 1.77523208, ...,        nan,        nan,
#                nan]),
#  'SubhaloCM': array([[  832.38696289, 26368.5234375 , 18060.82617188],
#         [  124.47653198, 24606.76757812, 16859.10351562],
#         [  850.36553955, 26710.41992188, 17508.05664062],
#         ...,
#         [70014.109375  , 20824.64257812, 70093.15625   ],
#         [71619.1015625 , 23868.9921875 , 51626.59765625],
#         [71026.265625  , 23052.53515625, 52052.97265625]]),
#  'SubhaloFlag': array([ True,  True,  True, ...,  True,  True,  True]),
#  'SubhaloGasMetalFractions': array([[7.44032204e-01, 2.48249605e-01, 8.17974214e-04, ...,
#          3.59014870e-04, 5.69847180e-04, 2.74896796e-04],
#         [7.43763328e-01, 2.47990146e-01, 8.33355240e-04, ...,
#          3.96070507e-04, 6.94443879e-04, 3.23803513e-04],
#         [7.38021314e-01, 2.50765651e-01, 1.14692794e-03, ...,
#          5.03961637e-04, 6.53538387e-04, 3.40341881e-04],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]),
#  'SubhaloGasMetalFractionsHalfRad': array([[7.43472219e-01, 2.48532906e-01, 8.43946822e-04, ...,
#          3.73769406e-04, 6.05325215e-04, 2.89858930e-04],
#         [7.37696648e-01, 2.50964046e-01, 1.12456060e-03, ...,
#          5.57941094e-04, 1.08418555e-03, 4.87347483e-04],
#         [7.35487282e-01, 2.52030641e-01, 1.28348300e-03, ...,
#          5.65031020e-04, 7.78757385e-04, 3.94788338e-04],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]),
#  'SubhaloGasMetalFractionsMaxRad': array([[7.48327732e-01, 2.46055871e-01, 5.99364052e-04, ...,
#          2.57479900e-04, 3.78113211e-04, 1.88218371e-04],
#         [7.52448618e-01, 2.43950680e-01, 3.77346732e-04, ...,
#          1.63599412e-04, 2.19597510e-04, 1.13687362e-04],
#         [7.39928126e-01, 2.49849468e-01, 1.03381334e-03, ...,
#          4.60719282e-04, 5.85361267e-04, 3.08603107e-04],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]),
#  'SubhaloGasMetalFractionsSfr': array([[7.46547043e-01, 2.46764451e-01, 6.32758136e-04, ...,
#          3.03988927e-04, 3.35602061e-04, 1.91823914e-04],
#         [7.45730877e-01, 2.47024566e-01, 7.05387269e-04, ...,
#          3.36313096e-04, 4.56414651e-04, 2.36931082e-04],
#         [7.39096761e-01, 2.50160605e-01, 1.07482634e-03, ...,
#          4.81984520e-04, 5.87812625e-04, 3.15561105e-04],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]),
#  'SubhaloGasMetalFractionsSfrWeighted': array([[7.46556759e-01, 2.46763170e-01, 6.28452050e-04, ...,
#          3.03683948e-04, 3.31808260e-04, 1.90765786e-04],
#         [7.45356381e-01, 2.47184321e-01, 7.24141661e-04, ...,
#          3.47354013e-04, 4.78555448e-04, 2.46885087e-04],
#         [7.38565087e-01, 2.50407875e-01, 1.10688631e-03, ...,
#          4.94180422e-04, 6.05676090e-04, 3.24171211e-04],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]),
#  'SubhaloGasMetallicity': array([0.0077182 , 0.00824652, 0.01121304, ..., 0.        , 0.        ,
#         0.        ]),
#  'SubhaloGasMetallicityHalfRad': array([0.00799488, 0.01133932, 0.01248207, ..., 0.        , 0.        ,
#         0.        ]),
#  'SubhaloGasMetallicityMaxRad': array([0.0056164 , 0.00360071, 0.01022238, ..., 0.        , 0.        ,
#         0.        ]),
#  'SubhaloGasMetallicitySfr': array([0.00668848, 0.00724458, 0.01074263, ..., 0.        , 0.        ,
#         0.        ]),
#  'SubhaloGasMetallicitySfrWeighted': array([0.00668008, 0.00745928, 0.01102702, ..., 0.        , 0.        ,
#         0.        ]),
#  'SubhaloGrNr': array([      0,       0,       0, ..., 6291318, 6291321, 6291342],
#        dtype=int32),
#  'SubhaloHalfmassRad': array([607.96569824, 300.95880127,  78.24937439, ...,   2.24959588,
#           3.88353157,   6.60955858]),
#  'SubhaloHalfmassRadType': array([[627.31060791, 610.31036377,   0.        ,   0.        ,
#           47.38805771,   0.        ],
#         [368.52603149, 291.90380859,   0.        ,   0.        ,
#           17.0123806 ,   0.        ],
#         [ 49.6453743 ,  82.63892365,   0.        ,   0.        ,
#           14.98396873,   0.        ],
#         ...,
#         [  0.        ,   2.24959588,   0.        ,   0.        ,
#            0.        ,   0.        ],
#         [  0.        ,   3.88353157,   0.        ,   0.        ,
#            0.        ,   0.        ],
#         [  0.        ,   6.60955858,   0.        ,   0.        ,
#            0.        ,   0.        ]]),
#  'SubhaloIDMostbound': array([120025224909, 108587636843, 120540440646, ...,   6027826629,
#           6027762537,   6028503637], dtype=uint64),
#  'SubhaloLen': array([88772413, 11346853,  2202646, ...,       30,       29,       28],
#        dtype=int32),
#  'SubhaloLenType': array([[38648183, 46136876,        0,        0,  3987343,       11],
#         [ 4454136,  6297959,        0,        0,   594757,        1],
#         [  114637,  1420531,        0,        0,   667477,        1],
#         ...,
#         [       0,       30,        0,        0,        0,        0],
#         [       0,       29,        0,        0,        0,        0],
#         [       0,       28,        0,        0,        0,        0]],
#        dtype=int32),
#  'SubhaloMass': array([2.74779355e+04, 3.66662280e+03, 7.73455505e+02, ...,
#         1.51672289e-02, 1.46616548e-02, 1.41560799e-02]),
#  'SubhaloMassInHalfRad': array([555.35583496,  60.34544373,  64.3336792 , ...,   0.        ,
#           0.        ,   0.        ]),
#  'SubhaloMassInHalfRadType': array([[1.35311031e+01, 4.15618988e+02, 0.00000000e+00, 0.00000000e+00,
#          1.25508087e+02, 6.97651565e-01],
#         [2.01577976e-01, 4.10920677e+01, 0.00000000e+00, 0.00000000e+00,
#          1.89262314e+01, 1.25566334e-01],
#         [3.19852591e-01, 4.25951385e+01, 0.00000000e+00, 0.00000000e+00,
#          2.12411995e+01, 1.77487046e-01],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#          0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#          0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#          0.00000000e+00, 0.00000000e+00]]),
#  'SubhaloMassInMaxRad': array([7.61122412e+03, 2.31738647e+03, 3.51638519e+02, ...,
#         4.55016876e-03, 6.06689136e-03, 4.55016876e-03]),
#  'SubhaloMassInMaxRadType': array([[8.70236023e+02, 6.51897266e+03, 0.00000000e+00, 0.00000000e+00,
#          2.21317459e+02, 6.98100448e-01],
#         [2.30714584e+02, 2.04946362e+03, 0.00000000e+00, 0.00000000e+00,
#          3.70826683e+01, 1.25566334e-01],
#         [8.58442593e+00, 3.05819855e+02, 0.00000000e+00, 0.00000000e+00,
#          3.70567360e+01, 1.77487046e-01],
#         ...,
#         [0.00000000e+00, 4.55016876e-03, 0.00000000e+00, 0.00000000e+00,
#          0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 6.06689136e-03, 0.00000000e+00, 0.00000000e+00,
#          0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 4.55016876e-03, 0.00000000e+00, 0.00000000e+00,
#          0.00000000e+00, 0.00000000e+00]]),
#  'SubhaloMassInRad': array([1549.86657715,  148.7603302 ,  140.44581604, ...,    0.        ,
#            0.        ,    0.        ]),
#  'SubhaloMassInRadType': array([[8.01218872e+01, 1.30521240e+03, 0.00000000e+00, 0.00000000e+00,
#          1.63834213e+02, 6.98100448e-01],
#         [1.07298613e+00, 1.21830765e+02, 0.00000000e+00, 0.00000000e+00,
#          2.57310143e+01, 1.25566334e-01],
#         [2.82840753e+00, 1.08587250e+02, 0.00000000e+00, 0.00000000e+00,
#          2.88526783e+01, 1.77487046e-01],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#          0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#          0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#          0.00000000e+00, 0.00000000e+00]]),
#  'SubhaloMassType': array([[3.90059814e+03, 2.33256191e+04, 0.00000000e+00, 0.00000000e+00,
#          2.51016312e+02, 7.01810956e-01],
#         [4.44558533e+02, 3.18408618e+03, 0.00000000e+00, 0.00000000e+00,
#          3.78525505e+01, 1.25566334e-01],
#         [1.26116333e+01, 7.18183960e+02, 0.00000000e+00, 0.00000000e+00,
#          4.24824371e+01, 1.77487046e-01],
#         ...,
#         [0.00000000e+00, 1.51672289e-02, 0.00000000e+00, 0.00000000e+00,
#          0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 1.46616548e-02, 0.00000000e+00, 0.00000000e+00,
#          0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 1.41560799e-02, 0.00000000e+00, 0.00000000e+00,
#          0.00000000e+00, 0.00000000e+00]]),
#  'SubhaloParent': array([0, 0, 0, ..., 0, 0, 0], dtype=int32),
#  'SubhaloPos': array([[  849.09143066, 26326.99609375, 18306.93359375],
#         [  106.47333527, 24633.32226562, 16900.55273438],
#         [  853.11236572, 26725.74804688, 17510.6796875 ],
#         ...,
#         [70013.0625    , 20824.58398438, 70093.6875    ],
#         [71621.484375  , 23869.9921875 , 51625.5625    ],
#         [71024.9765625 , 23053.        , 52052.71484375]]),
#  'SubhaloSFR': array([ 2.22718906,  0.41328505, 17.39220428, ...,  0.        ,
#          0.        ,  0.        ]),
#  'SubhaloSFRinHalfRad': array([0.        , 0.04907542, 0.71805143, ..., 0.        , 0.        ,
#         0.        ]),
#  'SubhaloSFRinMaxRad': array([ 0.90349483,  0.39511108, 13.34392738, ...,  0.        ,
#          0.        ,  0.        ]),
#  'SubhaloSFRinRad': array([0.19582452, 0.08808479, 5.29421473, ..., 0.        , 0.        ,
#         0.        ]),
#  'SubhaloSpin': array([[ 1.79978457e+04, -3.81015674e+03, -2.44809082e+04],
#         [ 1.27969404e+04, -1.32100654e+04,  1.42631553e+04],
#         [ 2.47231616e+03,  6.43015283e+03,  5.52146851e+02],
#         ...,
#         [ 7.11320925e+00, -2.28286552e+00, -9.14298519e-02],
#         [ 5.52278423e+00,  1.51462352e+00, -4.97966480e+00],
#         [ 8.41698933e+00,  2.30289340e-01,  5.19509733e-01]]),
#  'SubhaloStarMetalFractions': array([[7.10639000e-01, 2.60738671e-01, 3.07896244e-03, ...,
#          1.19871972e-03, 1.25940319e-03, 6.99458935e-04],
#         [7.26466358e-01, 2.52268553e-01, 2.19019642e-03, ...,
#          9.10362229e-04, 9.24620603e-04, 5.32502949e-04],
#         [7.18640864e-01, 2.55952209e-01, 2.67985626e-03, ...,
#          1.07352226e-03, 1.11570500e-03, 6.28217647e-04],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]),
#  'SubhaloStarMetalFractionsHalfRad': array([[7.03655839e-01, 2.63766617e-01, 3.54960677e-03, ...,
#          1.35815155e-03, 1.44495175e-03, 7.94396445e-04],
#         [7.23248482e-01, 2.53127307e-01, 2.46017589e-03, ...,
#          1.00781722e-03, 1.03389681e-03, 5.90650656e-04],
#         [7.14598775e-01, 2.57281899e-01, 2.98820739e-03, ...,
#          1.18204812e-03, 1.22619211e-03, 6.88577536e-04],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]),
#  'SubhaloStarMetalFractionsMaxRad': array([[7.18653023e-01, 2.57362902e-01, 2.54024845e-03, ...,
#          1.01036427e-03, 1.04697177e-03, 5.88467112e-04],
#         [7.32030272e-01, 2.50389636e-01, 1.77753018e-03, ...,
#          7.57265021e-04, 7.57131376e-04, 4.41891985e-04],
#         [7.22439587e-01, 2.54631132e-01, 2.39968509e-03, ...,
#          9.73160844e-04, 1.01042481e-03, 5.71056386e-04],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]),
#  'SubhaloStarMetallicity': array([0.02862233, 0.02126505, 0.02540692, ..., 0.        , 0.        ,
#         0.        ]),
#  'SubhaloStarMetallicityHalfRad': array([0.03257757, 0.02362422, 0.02811933, ..., 0.        , 0.        ,
#         0.        ]),
#  'SubhaloStarMetallicityMaxRad': array([0.02398407, 0.01758008, 0.0229293 , ..., 0.        , 0.        ,
#         0.        ]),
#  'SubhaloStellarPhotometrics': array([[-2.41033401e+01, -2.45115490e+01, -2.53760223e+01, ...,
#          -2.57157974e+01, -2.60726280e+01, -2.63285999e+01],
#         [-2.21142006e+01, -2.24990654e+01, -2.33480186e+01, ...,
#          -2.36832848e+01, -2.40339184e+01, -2.42838955e+01],
#         [-2.30677452e+01, -2.31290607e+01, -2.37847080e+01, ...,
#          -2.40691738e+01, -2.43691330e+01, -2.45975437e+01],
#         ...,
#         [ 9.99999993e+36,  9.99999993e+36,  9.99999993e+36, ...,
#           9.99999993e+36,  9.99999993e+36,  9.99999993e+36],
#         [ 9.99999993e+36,  9.99999993e+36,  9.99999993e+36, ...,
#           9.99999993e+36,  9.99999993e+36,  9.99999993e+36],
#         [ 9.99999993e+36,  9.99999993e+36,  9.99999993e+36, ...,
#           9.99999993e+36,  9.99999993e+36,  9.99999993e+36]]),
#  'SubhaloStellarPhotometricsMassInRad': array([139.71247864,  21.47511864,  27.32500458, ...,   0.        ,
#           0.        ,   0.        ]),
#  'SubhaloStellarPhotometricsRad': array([39.7722702 , 17.20243073, 19.17648888, ...,  0.        ,
#          0.        ,  0.        ]),
#  'SubhaloVel': array([[  15.84963036, -236.39202881,  -89.52388   ],
#         [ 126.42460632,  659.36126709,  540.56768799],
#         [ 322.07910156, -886.25866699, 1115.19897461],
#         ...,
#         [ 109.42255402,  290.94277954,  166.36761475],
#         [ 180.06985474,   35.79874039,  -16.9746933 ],
#         [ 166.134552  ,   11.46700668,  -16.62210846]]),
#  'SubhaloVelDisp': array([603.87506104, 333.89324951, 297.57727051, ...,   6.18831158,
#           5.314219  ,   4.01988411]),
#  'SubhaloVmax': array([999.38513184, 514.77587891, 461.64126587, ...,  13.21792793,
#           9.8306303 ,   8.06529522]),
#  'SubhaloVmaxRad': array([327.82806396, 376.20065308,  70.98149872, ...,   1.24484587,
#           2.92565441,   3.34350371]),
#  'SubhaloWindMass': array([0.03918033, 0.01582756, 0.        , ..., 0.        , 0.        ,
#         0.        ])}

# %% [markdown]
# Detailed description of each Field (e.g. ```SubhaloMass```) can be found here https://www.tng-project.org/data/docs/specifications/#sec2

# %% [markdown]
# Analogously, you can also load group catalogs of the halos (AKA FoF halos):

# %%
# Specify just some columns of interest
fields = ['GroupMass','GroupSFR']   

# Load the sliced group catalog of subhalos
halos = il.groupcat.loadHalos(basePath, snapshot, fields=fields)

# %%
halos
# Out:
# {'count': 6291349,
#  'GroupMass': array([3.88780352e+04, 3.31809922e+04, 2.67200742e+04, ...,
#         3.51541070e-03, 3.60588450e-03, 3.15259537e-03]),
#  'GroupSFR': array([98.86584473, 29.31518173, 14.18533611, ...,  0.        ,
#          0.        ,  0.        ])}

# %% [markdown]
# And they are also returned as a dictionary.
# ***

# %% [markdown]
# One important aspect of the data structure is that the index of the arrays in each column, correspond to the Subhalo ID of the respective subhalo/halo.
#
# For example, consider the subhalo catalog that we loaded some cells above. Lets say I want to check the mass of Subhalo 11.
#
# Then, I must do:

# %%
subhalo_ID = 11
subhalos['SubhaloMass'][subhalo_ID]
# Out:
# 46.31220245361328

# %% [markdown]
# We can compare it by searching the catalog in the [web interface](https://www.tng-project.org/data/search/?sim=TNG100-1&snap=99), and as we can see, the value is the same (disconsidering the rounding).

# %% [markdown]
# ![image](figures/web_cat_interface.jpeg)
